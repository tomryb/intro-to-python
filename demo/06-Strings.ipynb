# %% [markdown]
# # Łańcuchy znaków

# %%
text1 = 'Ala ma kota'
text2 = "Ala ma kota"

text3 = """Ala
    ma
kota
"""

print(text1)
print(text2)
print(text3)

# %%
unicode_text = "🌙 🐕"
print(unicode_text)

# %%
s = 'abcde'
b = b'abcde'

print(type(s))
print(type(b))

# %%
s = 'Zażółć gęślą jaźń'

b = b'Zażółć gęślą jaźń'

# %% [markdown]
# # Formatowanie łańcuchów znaków

# %%
x = 3
y = 4
name = 'John'

s = '{} + {} = {}'.format(x, y, x+y)
print(s)

print('Hello {}'.format(name))

# %%
x = 3
y = 4
name = 'John'

s = f'{x} + {y} = {x+y}'
print(s)
print(f'Hello {name}')

# %% [markdown]
# # Operacje na łańcuchach znaków

# %%
s = 'Ala ma kota'
s.split()

# %%
s = 'Ala       ma    \tkota   '
print(s.split(' '))
print(s.split())

# %%
s = "Ala ma kota"
words = s.split()
print(words)
print('-'.join(words))

# %%
s = '   Ala     ma     kota   '
s.strip()

# %%
s = '   Ala     ma     kota   '
s.rstrip()

# %%
s = '   Ala     ma     kota   '
s.lstrip()

# %%
s = "alA Ma kota"
print(s.upper())
print(s.lower())
print(s.capitalize())

# %%
s = "Ala ma kota"
print(s.find('a'))
print(s.rfind('a'))
print(s.find('Z'))
